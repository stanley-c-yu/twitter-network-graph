# %%
# Import Dependencies & Data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
smv_dataset = pd.read_csv("fulldata.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4a9723fb69a8> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 from sklearn.model_selection import train_test_split
#       5 smv_dataset = pd.read_csv("fulldata.csv")
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in <module>
#      18
#      19 from . import __version__
# ---> 20 from .utils import _IS_32BIT
#      21
#      22 _DEFAULT_TAGS = {
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py in <module>
# ...

# %%
smv_dataset.head()
# Out:
#                TIME_STAMPS  SMV_Avg1  SMV_Avg2  SMV_Avg3  SMV_Avg4  SMV_Avg5  \
# 0  2015-09-24 14:35:20.200  1.220043  1.026965  0.963636  1.029917  0.993936
# 1  2015-09-24 14:35:33.000  1.175729  1.022705  0.963321  1.028854  0.983839
# 2  2015-09-24 14:35:45.800  1.032820  1.009889  0.963268  1.028000  0.983577
# 3  2015-09-24 14:35:58.600  1.022319  1.023136  0.962320  1.026720  0.986485
# 4  2015-09-24 14:36:37.000  1.213542  1.020577  0.968407  1.029251  0.985690
#
#    SMV_Avg6  SMV_Avg7  SMV_Std_Dev1  SMV_Std_Dev2  SMV_Std_Dev3  SMV_Std_Dev4  \
# 0  0.988680  1.000859      0.710514      0.053948      0.012507      0.019950
# 1  0.988937  1.000367      0.643705      0.004885      0.004128      0.003316
# 2  0.989042  1.002219      0.076293      0.128312      0.004952      0.005939
# 3  0.989368  1.007674      0.025779      0.027558      0.007803      0.023449
# 4  1.002151  1.008572      0.820113      0.020092      0.003965      0.004437
#
# ...

# %%
smv_dataset.tail()
# Out:
#                  TIME_STAMPS  SMV_Avg1  SMV_Avg2  SMV_Avg3  SMV_Avg4  \
# 147  2015-09-24 14:59:01.000  1.022172  1.123451  1.013274  1.071947
# 148  2015-09-24 14:59:13.800  1.023774  1.117941  1.018264  1.066311
# 149  2015-09-24 14:59:13.800  1.023774  1.117941  1.018264  1.066311
# 150  2015-09-24 14:59:26.600  1.030695  1.115555  1.014088  1.073057
# 151  2015-09-24 14:59:26.600  1.030695  1.115555  1.014088  1.073057
#
#      SMV_Avg5  SMV_Avg6  SMV_Avg7  SMV_Std_Dev1  SMV_Std_Dev2  SMV_Std_Dev3  \
# 147  1.039052  1.471831  1.422338      0.021559      0.257830      0.347001
# 148  1.065132  1.526257  1.447088      0.020074      0.319562      0.358265
# 149  1.065132  1.526257  1.447088      0.020074      0.319562      0.358265
# 150  1.048068  1.477439  1.417499      0.044541      0.300278      0.361964
# 151  1.048068  1.477439  1.417499      0.044541      0.300278      0.361964
#
#      SMV_Std_Dev4  SMV_Std_Dev5  SMV_Std_Dev6  SMV_Std_Dev7    LABELS
# ...

# %%
# Randomize so that differenct classes of activity are randomly distributed throughout 
data = smv_dataset.sample(frac=1)

features = data.iloc[:,1:14]
print("Features has dimensions: ", np.shape(features))
print("Features has the following columns: ", list(features.columns))
# Train-Test-Split the data 
# X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.3,random_state=109) # 70% training and 30% test
# Out:
# Features has dimensions:  (152, 13)
# Features has the following columns:  ['SMV_Avg1', 'SMV_Avg2', 'SMV_Avg3', 'SMV_Avg4', 'SMV_Avg5', 'SMV_Avg6', 'SMV_Avg7', 'SMV_Std_Dev1', 'SMV_Std_Dev2', 'SMV_Std_Dev3', 'SMV_Std_Dev4', 'SMV_Std_Dev5', 'SMV_Std_Dev6']
