# %%
#Import dependencies 
import pandas as pd 
from loadData import loadData
loader = loadData()

# %%
#Read in data 
filenames = ["Attribute.txt", "Class_info.txt", "edgelist.txt", "Statistics.txt", "vertex2aid.txt"]
prefix = "data/twitter/"

# %%
attributes = pd.read_csv(prefix + filenames[0], header = None, delim_whitespace=True, encoding = "ISO-8859-1")

# %%
edgeList = pd.read_csv(prefix + filenames[2], header = None, delim_whitespace=True)

# %%
stats = pd.read_csv(prefix + filenames[3], header = None)

# %%
vertex2aid = pd.read_csv(prefix + filenames[4], header = None, delim_whitespace=True)

# %%
vertex2aid
# Out:
#           0     1
# 0         0   130
# 1         0    74
# 2         0   245
# 3         0   554
# 4         1   538
# 5         1   412
# 6         1   325
# 7         1   172
# 8         1   189
# 9         1   300
# 10        1   495
# 11        1   409
# 12        1   410
# 13        1   572
# 14        2   360
# 15        2   191
# 16        2   417
# 17        2   504
# 18        2   401
# 19        2   388
# 20        2   398
# 21        2   344
# 22        2   511
# 23        2   290
# 24        4   150
# 25        4   164
# 26        4    74
# 27        4   158
# 28        4   550
# 29        4   274
# ...     ...   ...
# 32782  2507  8677
# 32783  2507  8678
# 32784  2507  8869
# 32785  2507  8728
# 32786  2507  8786
# 32787  2507  8660
# 32788  2507  8691
# 32789  2507  7335
# 32790  2507  7450
# 32791  2507  9050
# 32792  2507  8961
# 32793  2507  8996
# 32794  2507   424
# 32795  2507  8948
# 32796  2507  7425
# 32797  2507  8668
# 32798  2507   531
# 32799  2510  8755
# ...
